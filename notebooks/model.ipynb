# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'D:\CarDekhoModel\notebooks\data\cardekho_dataset.csv')
df.head()
# Out:
#    Unnamed: 0       car_name    brand     model  vehicle_age  km_driven  \
# 0           0    Maruti Alto   Maruti      Alto            9     120000
# 1           1  Hyundai Grand  Hyundai     Grand            5      20000
# 2           2    Hyundai i20  Hyundai       i20           11      60000
# 3           3    Maruti Alto   Maruti      Alto            9      37000
# 4           4  Ford Ecosport     Ford  Ecosport            6      30000
#
#   seller_type fuel_type transmission_type  mileage  engine  max_power  seats  \
# 0  Individual    Petrol            Manual    19.70     796      46.30      5
# 1  Individual    Petrol            Manual    18.90    1197      82.00      5
# 2  Individual    Petrol            Manual    17.00    1197      80.00      5
# 3  Individual    Petrol            Manual    20.92     998      67.10      5
# 4      Dealer    Diesel            Manual    22.77    1498      98.59      5
#
#    selling_price
# 0         120000
# 1         550000
# 2         215000
# 3         226000
# 4         570000

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.shape
# Out:
# (15411, 13)

# %%
df.head()
# Out:
#         car_name    brand     model  vehicle_age  km_driven seller_type  \
# 0    Maruti Alto   Maruti      Alto            9     120000  Individual
# 1  Hyundai Grand  Hyundai     Grand            5      20000  Individual
# 2    Hyundai i20  Hyundai       i20           11      60000  Individual
# 3    Maruti Alto   Maruti      Alto            9      37000  Individual
# 4  Ford Ecosport     Ford  Ecosport            6      30000      Dealer
#
#   fuel_type transmission_type  mileage  engine  max_power  seats  \
# 0    Petrol            Manual    19.70     796      46.30      5
# 1    Petrol            Manual    18.90    1197      82.00      5
# 2    Petrol            Manual    17.00    1197      80.00      5
# 3    Petrol            Manual    20.92     998      67.10      5
# 4    Diesel            Manual    22.77    1498      98.59      5
#
#    selling_price
# 0         120000
# 1         550000
# 2         215000
# 3         226000
# 4         570000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15411 entries, 0 to 15410
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   car_name           15411 non-null  object
#  1   brand              15411 non-null  object
#  2   model              15411 non-null  object
#  3   vehicle_age        15411 non-null  int64
#  4   km_driven          15411 non-null  int64
#  5   seller_type        15411 non-null  object
#  6   fuel_type          15411 non-null  object
#  7   transmission_type  15411 non-null  object
#  8   mileage            15411 non-null  float64
#  9   engine             15411 non-null  int64
#  10  max_power          15411 non-null  float64
#  11  seats              15411 non-null  int64
#  12  selling_price      15411 non-null  int64
# dtypes: float64(2), int64(5), object(6)
# memory usage: 1.5+ MB

# %%
df.isnull().sum()
# Out:
# car_name             0
# brand                0
# model                0
# vehicle_age          0
# km_driven            0
# seller_type          0
# fuel_type            0
# transmission_type    0
# mileage              0
# engine               0
# max_power            0
# seats                0
# selling_price        0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (15244, 13)

# %%
X=df.drop(['selling_price'],axis=1)
y=df['selling_price']

# %% [markdown]
# ## Segrigating categorical and Numerical Columns:

# %%
df.head(1)
# Out:
#       car_name   brand model  vehicle_age  km_driven seller_type fuel_type  \
# 0  Maruti Alto  Maruti  Alto            9     120000  Individual    Petrol
#
#   transmission_type  mileage  engine  max_power  seats  selling_price
# 0            Manual     19.7     796       46.3      5         120000

# %%
categorical_column=X.select_dtypes(include='object')
numerical_column=X.select_dtypes(exclude='object')

# %%
numerical_column.columns
# Out:
# Index(['vehicle_age', 'km_driven', 'mileage', 'engine', 'max_power', 'seats'], dtype='object')

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OrdinalEncoder

# %%
num_pipeline=Pipeline(steps=[
    ('imputer',SimpleImputer(strategy='median')),
    ('scaler',StandardScaler())   
])

# %%
cat_pipeline=Pipeline(steps=[
    ('imputer',SimpleImputer(strategy='most_frequent')),
    ('encoder',OrdinalEncoder()),
    ('scaler',StandardScaler())   
])

# %%
preprocessor=ColumnTransformer([
    ('num_pipeline',num_pipeline,numerical_column.columns.tolist()),
    ('cat_pipeline',cat_pipeline,categorical_column.columns.tolist())
])

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('num_pipeline',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  ['vehicle_age', 'km_driven', 'mileage',
#                                   'engine', 'max_power', 'seats']),
#                                 ('cat_pipeline',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('encoder', OrdinalEncoder()),
#                                                  ('scaler', StandardScaler())]),
#                                  ['car_name', 'brand', 'model', 'seller_type',
#                                   'fuel_type', 'transmission_type'])])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,y,test_size=0.25,random_state=256)

# %%
X_train.shape,Y_train.shape,X_test.shape,Y_test.shape
# Out:
# ((11433, 12), (11433,), (3811, 12), (3811,))

# %%
df[df['car_name']=='ISUZU MUX']
# Out:
#         car_name  brand model  vehicle_age  km_driven seller_type fuel_type  \
# 3553   ISUZU MUX  ISUZU   MUX            4      65029      Dealer    Diesel
# 14780  ISUZU MUX  ISUZU   MUX            4      47000      Dealer    Diesel
#
#       transmission_type  mileage  engine  max_power  seats  selling_price
# 3553          Automatic     13.8    2999      175.0      7        1895000
# 14780         Automatic     13.8    2999      175.0      7        1900000

# %%
X_test['car_name'].value_counts()==1
# Out:
# car_name
# Maruti Swift Dzire    False
# Hyundai i20           False
# Maruti Alto           False
# Maruti Swift          False
# Maruti Wagon R        False
#                       ...
# Porsche Panamera       True
# Volvo XC60             True
# Nissan Kicks           True
# BMW X4                 True
# Maruti Dzire LXI       True
# Name: count, Length: 100, dtype: bool

# %%
x_train=preprocessor.fit_transform(X_train)
x_test=preprocessor.transform(X_test)

# %%
X_train=pd.DataFrame(x_train,columns=preprocessor.get_feature_names_out())
X_test=pd.DataFrame(x_test,columns=preprocessor.get_feature_names_out())

# %%
x_test.shape
# Out:
# (3811, 12)

# %%
X_train.shape
# Out:
# (11433, 12)

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from xgboost import XGBRegressor

# %%
models = {     
    "Linear Regression": LinearRegression(),
    'Ridge Regression':Ridge(),
    'Lasso Regression':Lasso(),
    'Elasticnet Regression':ElasticNet(),
    'SVR':SVR(),
    "Decision Tree": DecisionTreeRegressor(),
    'KNeighborsRegressor':KNeighborsRegressor(algorithm='auto'),
    "Random Forest": RandomForestRegressor(),
    'AdaboostRegressor':AdaBoostRegressor(),
    "XGBRegressor": XGBRegressor(),
            }

# %%
params={
    "Linear Regression":{},
    
    'Ridge Regression':{},
    
    'Lasso Regression':{},
    'Elasticnet Regression':{},
    
    'SVR':{
        # 'kernel':['linear', 'poly', 'rbf', 'sigmoid', 'precomputed'],
        'C':[0.1,0.5,1,1.5,2.5],
        },
    
    
    'Decision Tree': {
        'splitter':['best','random'],
        # 'criterion':['gini', 'entropy', 'log_loss'],
        'max_depth':[5,10,15,20,25,30,35,40,45,50],
        'max_features':['sqrt','log2'],
    },
    
    'KNeighborsRegressor':{
        'n_neighbors':[3,4,5,6,7,8,9,10],
        
    },
    
    "Random Forest":{
        'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],

        'max_features':['sqrt','log2',None],
        'n_estimators': [8,16,32,64,128,256]
    },
    
    'AdaboostRegressor':{

    },
    
    
    'XGBRegressor':{
        'learning_rate':[.1,.01,.05,.001],
        'n_estimators': [8,16,32,64,128,256]
    } 
}

# %%
from sklearn.metrics import r2_score
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV
def get_best_model(X_train,y_train,X_test,y_test,model_dict,params_,base_accuracy=0.7):
    models = model_dict.keys()
    for model in models:
        print(f'Initial base accuracy is {base_accuracy}')
        print(20*'*',"Estimator: ",model,20*'*')
        gs = GridSearchCV(estimator=model_dict[model],param_grid=params_[model],cv=3)
        gs.fit(X_train,y_train)
        print(f'Best parameters are :{gs.best_params_} With R2 score:{gs.best_score_}')
        
        regressor = model_dict[model].set_params(**gs.best_params_)
        regressor.fit(X_train,y_train)

        y_train_pred = regressor.predict(X_train)
        y_test_pred = regressor.predict(X_test)
        
        train_model_score = r2_score(y_train, y_train_pred)

        test_model_score = r2_score(y_test, y_test_pred)
        
        if test_model_score >= base_accuracy:
            print('Acceptabel model found!')
            base_accuracy = test_model_score
            best_model = {model:regressor}
        else:
            print('Model rejected\n',30*'__')
            
    
    print(f"Best model is:{list(best_model.keys())} with R2 Score: {round(test_model_score,2)}")        
    return best_model

# %%
get_best_model(X_train,Y_train,X_test,Y_test,model_dict=models,params_=params)
# Out:
# Initial base accuracy is 0.7
# ******************** Estimator:  Linear Regression ********************
# Best parameters are :{} With R2 score:0.6197617197169728
# Model rejected
#  ____________________________________________________________
# Initial base accuracy is 0.7
# ******************** Estimator:  Ridge Regression ********************
# Best parameters are :{} With R2 score:0.6197926609864147
# Model rejected
#  ____________________________________________________________
# Initial base accuracy is 0.7
# ******************** Estimator:  Lasso Regression ********************
# e:\DATA SCIENCE 101 DAYS CHALENGE\abhi\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.006e+14, tolerance: 7.043e+11
#   model = cd_fast.enet_coordinate_descent(
# e:\DATA SCIENCE 101 DAYS CHALENGE\abhi\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.275e+14, tolerance: 6.752e+11
#   model = cd_fast.enet_coordinate_descent(
# e:\DATA SCIENCE 101 DAYS CHALENGE\abhi\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.669e+13, tolerance: 5.828e+11
#   model = cd_fast.enet_coordinate_descent(
# e:\DATA SCIENCE 101 DAYS CHALENGE\abhi\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.358e+14, tolerance: 9.812e+11
#   model = cd_fast.enet_coordinate_descent(
# Best parameters are :{} With R2 score:0.6197622894559623
# e:\DATA SCIENCE 101 DAYS CHALENGE\abhi\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.358e+14, tolerance: 9.812e+11
#   model = cd_fast.enet_coordinate_descent(
# Model rejected
#  ____________________________________________________________
# Initial base accuracy is 0.7
# ******************** Estimator:  Elasticnet Regression ********************
# Best parameters are :{} With R2 score:0.5762882390027428
# Model rejected
#  ____________________________________________________________
# Initial base accuracy is 0.7
# ******************** Estimator:  SVR ********************
# Best parameters are :{'C': 2.5} With R2 score:-0.05653929072844566
# Model rejected
#  ____________________________________________________________
# Initial base accuracy is 0.7
# ******************** Estimator:  Decision Tree ********************
# Best parameters are :{'max_depth': 40, 'max_features': 'sqrt', 'splitter': 'best'} With R2 score:0.8275354489958583
# Acceptabel model found!
# Initial base accuracy is 0.8239329092869897
# ******************** Estimator:  KNeighborsRegressor ********************
# Best parameters are :{'n_neighbors': 3} With R2 score:0.779259127062018
# Acceptabel model found!
# Initial base accuracy is 0.8963895755754873
# ******************** Estimator:  Random Forest ********************
# Best parameters are :{'criterion': 'absolute_error', 'max_features': None, 'n_estimators': 256} With R2 score:0.8768841808812322
# Acceptabel model found!
# Initial base accuracy is 0.9221851963628407
# ******************** Estimator:  AdaboostRegressor ********************
# Best parameters are :{} With R2 score:0.6367998260321348
# Model rejected
#  ____________________________________________________________
# Initial base accuracy is 0.9221851963628407
# ******************** Estimator:  XGBRegressor ********************
# Best parameters are :{'learning_rate': 0.1, 'n_estimators': 32} With R2 score:0.7789126370691136
# Model rejected
#  ____________________________________________________________
# Best model is:['Random Forest'] with R2 Score: 0.92
# {'Random Forest': RandomForestRegressor(criterion='absolute_error', max_features=None,
#                        n_estimators=256)}

# %%
model=RandomForestRegressor(criterion='absolute_error',max_features=None,n_estimators=256)

# %%
model.fit(X_train,Y_train)
# Out:
# RandomForestRegressor(criterion='absolute_error', max_features=None,
#                       n_estimators=256)

# %%
y_pred=model.predict(X_test)

# %%
r2_score(Y_test,y_pred)
# Out:
# 0.9215237913772968
